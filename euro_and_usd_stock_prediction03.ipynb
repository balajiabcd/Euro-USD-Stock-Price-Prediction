# %% [markdown]
# <a href="https://colab.research.google.com/github/balajiabcd/Euro-USD-Stock-Price-Prediction/blob/main/euro_and_usd_stock_prediction03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Libraries

# %%
import numpy as np
import pandas as pd
from datetime import datetime,timedelta

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
data = pd.read_csv("/content/Entire.csv")
data.head()
# Out:
#                Date     Open     High      Low    Close  Volume
# 0  2020-12-02 09:53  1.20584  1.20586  1.20577  1.20583     263
# 1  2020-12-02 09:54  1.20583  1.20586  1.20577  1.20577     230
# 2  2020-12-02 09:55  1.20575  1.20589  1.20569  1.20586     268
# 3  2020-12-02 10:00  1.20536  1.20564  1.20530  1.20552     298
# 4  2020-12-02 10:01  1.20551  1.20563  1.20525  1.20542     481

# %% [markdown]
# # Data Analysis

# %%
data["Date"] =  [datetime.strptime(a, '%Y-%m-%d %H:%M') for a in data.Date]
data = data.sort_values(by = "Date").reset_index()
data = data.drop("index", axis = 1)
data["date"] =  [a.date() for a in data.Date]

# %%
data.head()
# Out:
#                  Date     Open     High      Low    Close   Volume        date
# 0 2007-01-01 00:00:00  1.31908  1.31973  1.31872  1.31952   145690  2007-01-01
# 1 2007-01-01 00:00:00  1.31908  1.32095  1.31650  1.32058  1946843  2007-01-01
# 2 2007-01-01 01:00:00  1.31908  1.31964  1.31896  1.31913    24827  2007-01-01
# 3 2007-01-01 01:00:00  1.31908  1.31964  1.31894  1.31915    47067  2007-01-01
# 4 2007-01-01 01:30:00  1.31920  1.31943  1.31894  1.31915    22240  2007-01-01

# %%
data.tail()
# Out:
#                       Date     Open     High      Low    Close  Volume  \
# 940398 2021-01-22 22:55:00  1.21701  1.21717  1.21666  1.21667    2352
# 940399 2021-01-22 22:56:00  1.21709  1.21712  1.21706  1.21709     564
# 940400 2021-01-22 22:57:00  1.21709  1.21710  1.21702  1.21706     690
# 940401 2021-01-22 22:58:00  1.21705  1.21709  1.21704  1.21706     473
# 940402 2021-01-22 22:59:00  1.21705  1.21717  1.21666  1.21667     249
#
#               date
# 940398  2021-01-22
# 940399  2021-01-22
# 940400  2021-01-22
# 940401  2021-01-22
# 940402  2021-01-22

# %%
date, volume, start, close, ave  = [],[],[],[],[] 
d, o, c, vol = data.date[0] - timedelta(1), 0, 0, 0
for i in range(len(data)):
    if d != data.date[i]:
        d = data.date[i]
        low_time = data.Date[i].time()
        high_time = data.Date[i].time()
        o, c, vol = data.Open[i], data.Close[i], data.Volume[i]
        date.append(d)
        volume.append(vol)
        start.append(o)
        close.append(c)
        ave.append((o+c)/2)
        
    if low_time > data.Date[i].time():
        low_time = data.Date[i].time()
        o = data.Open[i]
        
    if high_time < data.Date[i].time():
        high_time = data.Date[i].time()
        c = data.Close[i]
        
    if vol != data.Volume[i]:
        vol += data.Volume[i]

# %%
new_data = pd.DataFrame({ 
    'date' : date,
    'volume' : volume,
    'open' : start,
    'close': close,
    'ave' : ave })
print(len(new_data))
new_data.head()
# Out:
# 4398
#          date  volume     open    close       ave
# 0  2007-01-01  145690  1.31908  1.31952  1.319300
# 1  2007-01-02   25112  1.32033  1.32106  1.320695
# 2  2007-01-03   24481  1.32762  1.32710  1.327360
# 3  2007-01-04   23233  1.31626  1.31683  1.316545
# 4  2007-01-05   24544  1.30893  1.30845  1.308690

# %%
plt.figure(figsize = (20,6))
sns.lineplot(data=new_data, x="date", y="open")

# %%
plt.figure(figsize = (20,6))
sns.lineplot(data=new_data, x="date", y="close")

# %%
plt.figure(figsize = (20,6))
sns.lineplot(data=new_data, x="date", y="ave")

# %% [markdown]
# # Training and test set Preparation

# %%
ave = [a*100 for a in ave]

# %%
a = 5

# %%
X_data, y_data = [], []
for i in range(a,len(ave)):
    X_data.append( ave[i-a:i] )
    y_data.append( ave[i] )

len(X_data)
# Out:
# 4393

# %%
X_train, X_val, X_test = X_data[:3000], X_data[3000:3350], X_data[3350:]
y_train, y_val, y_test = y_data[:3000], y_data[3000:3350], y_data[3350:]

# %%
def arraying(s):
    return np.array(s)

def shapeshift(s):
    s = arraying(s)
    return np.reshape(s, (s.shape[0], s.shape[1], 1))

X_train, X_val, X_test = shapeshift(X_train), shapeshift(X_val), shapeshift(X_test)
y_train, y_val, y_test = arraying(y_train), arraying(y_val), arraying(y_test)

# %%
X_train.shape
# Out:
# (3000, 5, 1)

# %% [markdown]
# # Building RNN model (LSTM)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras import layers

# %%
model = Sequential([layers.Input((a,1)),
                    layers.LSTM(64),
                    layers.Dense(32, activation = "relu"),
                    layers.Dense(32, activation = "relu"),
                    layers.Dense(1)
                   ])

model.compile(loss="mse", optimizer = "Adam", metrics = ["mean_absolute_error"])

# %%
model.fit(X_train,y_train, validation_data = (X_val, y_val), epochs = 30)
# Out:
# Epoch 1/30
# 94/94 [==============================] - 3s 12ms/step - loss: 15424.5850 - mean_absolute_error: 123.1745 - val_loss: 5036.4946 - val_mean_absolute_error: 70.8315
# Epoch 2/30
# 94/94 [==============================] - 1s 6ms/step - loss: 1825.3276 - mean_absolute_error: 31.0157 - val_loss: 456.0455 - val_mean_absolute_error: 20.9206
# Epoch 3/30
# 94/94 [==============================] - 1s 6ms/step - loss: 127.4687 - mean_absolute_error: 8.6996 - val_loss: 214.2873 - val_mean_absolute_error: 14.2794
# Epoch 4/30
# 94/94 [==============================] - 1s 6ms/step - loss: 35.5827 - mean_absolute_error: 4.1059 - val_loss: 1.3237 - val_mean_absolute_error: 0.9248
# Epoch 5/30
# 94/94 [==============================] - 1s 7ms/step - loss: 2.5298 - mean_absolute_error: 1.0715 - val_loss: 2.0804 - val_mean_absolute_error: 1.1836
# Epoch 6/30
# 94/94 [==============================] - 1s 6ms/step - loss: 1.4519 - mean_absolute_error: 0.8694 - val_loss: 1.3754 - val_mean_absolute_error: 0.9855
# Epoch 7/30
# 94/94 [==============================] - 1s 6ms/step - loss: 1.1172 - mean_absolute_error: 0.7772 - val_loss: 0.8203 - val_mean_absolute_error: 0.7431
# Epoch 8/30
# 94/94 [==============================] - 1s 7ms/step - loss: 1.0307 - mean_absolute_error: 0.7447 - val_loss: 0.4085 - val_mean_absolute_error: 0.5060
# Epoch 9/30
# 94/94 [==============================] - 1s 6ms/step - loss: 0.8891 - mean_absolute_error: 0.6896 - val_loss: 0.4283 - val_mean_absolute_error: 0.5219
# Epoch 10/30
# 94/94 [==============================] - 1s 6ms/step - loss: 0.8454 - mean_absolute_error: 0.6682 - val_loss: 0.4134 - val_mean_absolute_error: 0.5162
# Epoch 11/30
# 94/94 [==============================] - 1s 6ms/step - loss: 0.8732 - mean_absolute_error: 0.6933 - val_loss: 0.3512 - val_mean_absolute_error: 0.4712
# Epoch 12/30
# 94/94 [==============================] - 1s 7ms/step - loss: 0.8781 - mean_absolute_error: 0.6982 - val_loss: 0.3938 - val_mean_absolute_error: 0.4999
# Epoch 13/30
# 94/94 [==============================] - 1s 7ms/step - loss: 0.9005 - mean_absolute_error: 0.7113 - val_loss: 0.4118 - val_mean_absolute_error: 0.5091
# Epoch 14/30
# 94/94 [==============================] - 1s 6ms/step - loss: 0.8269 - mean_absolute_error: 0.6777 - val_loss: 0.3048 - val_mean_absolute_error: 0.4316
# Epoch 15/30
# 94/94 [==============================] - 1s 7ms/step - loss: 0.7828 - mean_absolute_error: 0.6457 - val_loss: 0.6435 - val_mean_absolute_error: 0.6658
# Epoch 16/30
# 94/94 [==============================] - 1s 6ms/step - loss: 0.8810 - mean_absolute_error: 0.6974 - val_loss: 0.4389 - val_mean_absolute_error: 0.5350
# Epoch 17/30
# 94/94 [==============================] - 1s 6ms/step - loss: 0.9216 - mean_absolute_error: 0.7266 - val_loss: 0.5249 - val_mean_absolute_error: 0.6153
# Epoch 18/30
# 94/94 [==============================] - 1s 6ms/step - loss: 0.8270 - mean_absolute_error: 0.6735 - val_loss: 0.3626 - val_mean_absolute_error: 0.4873
# Epoch 19/30
# 94/94 [==============================] - 1s 6ms/step - loss: 0.8726 - mean_absolute_error: 0.7008 - val_loss: 0.4144 - val_mean_absolute_error: 0.5377
# Epoch 20/30
# 94/94 [==============================] - 1s 6ms/step - loss: 0.8375 - mean_absolute_error: 0.6804 - val_loss: 0.5865 - val_mean_absolute_error: 0.6625
# Epoch 21/30
# 94/94 [==============================] - 1s 6ms/step - loss: 0.7794 - mean_absolute_error: 0.6473 - val_loss: 0.2372 - val_mean_absolute_error: 0.3619
# Epoch 22/30
# 94/94 [==============================] - 1s 6ms/step - loss: 0.8982 - mean_absolute_error: 0.7199 - val_loss: 0.3803 - val_mean_absolute_error: 0.4876
# Epoch 23/30
# 94/94 [==============================] - 1s 6ms/step - loss: 0.8379 - mean_absolute_error: 0.6785 - val_loss: 0.5721 - val_mean_absolute_error: 0.6273
# Epoch 24/30
# 94/94 [==============================] - 1s 6ms/step - loss: 0.7719 - mean_absolute_error: 0.6438 - val_loss: 0.2369 - val_mean_absolute_error: 0.3617
# Epoch 25/30
# 94/94 [==============================] - 1s 6ms/step - loss: 0.7505 - mean_absolute_error: 0.6370 - val_loss: 1.1022 - val_mean_absolute_error: 0.9396
# Epoch 26/30
# 94/94 [==============================] - 1s 6ms/step - loss: 0.9489 - mean_absolute_error: 0.7454 - val_loss: 0.6495 - val_mean_absolute_error: 0.7003
# Epoch 27/30
# 94/94 [==============================] - 1s 6ms/step - loss: 0.7616 - mean_absolute_error: 0.6464 - val_loss: 0.7923 - val_mean_absolute_error: 0.7734
# Epoch 28/30
# 94/94 [==============================] - 1s 6ms/step - loss: 0.9391 - mean_absolute_error: 0.7320 - val_loss: 0.5234 - val_mean_absolute_error: 0.6250
# Epoch 29/30
# 94/94 [==============================] - 1s 6ms/step - loss: 0.7705 - mean_absolute_error: 0.6468 - val_loss: 0.2439 - val_mean_absolute_error: 0.3622
# Epoch 30/30
# 94/94 [==============================] - 1s 6ms/step - loss: 0.7772 - mean_absolute_error: 0.6572 - val_loss: 0.2536 - val_mean_absolute_error: 0.3739

# %% [markdown]
# # Train Set Results

# %%
y_train_pred = model.predict(X_train)

a, b = 200, 100

plt.figure(figsize = (15,6))
plt.plot(date[b:a], y_train_pred[b:a])
plt.plot(date[b:a], y_train[b:a])
plt.legend(["train preds", "acual vals"])

# %%
plt.figure(figsize = (15,6))
plt.plot(date[:3000], y_train_pred)
plt.plot(date[:3000], y_train)
plt.legend(["train preds", "acual vals"])

# %%
from sklearn.metrics import mean_absolute_error as mae
mae(y_train,y_train_pred)/100
# Out:
# 0.00568177942972819

# %% [markdown]
# # Test set predictions

# %%
y_pred = model.predict(X_test)

a, b = 200, 100

plt.figure(figsize = (15,6))
plt.plot(date[b:a], y_pred[b:a])
plt.plot(date[b:a], y_test[b:a])
plt.legend(["train preds", "acual vals"])

# %%
plt.figure(figsize = (15,6))
plt.plot(date[:1043], y_pred)
plt.plot(date[:1043], y_test)
plt.legend(["test preds", "acual vals"])

# %%
from sklearn.metrics import mean_absolute_error as mae
mae(y_test,y_pred)/100
# Out:
# 0.0035966193118511414
