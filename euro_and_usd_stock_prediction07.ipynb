# %% [markdown]
# <a href="https://colab.research.google.com/github/balajiabcd/Euro-USD-Stock-Price-Prediction/blob/main/euro_and_usd_stock_prediction07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Libraries

# %%
import numpy as np
import pandas as pd
from datetime import datetime,timedelta

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
data = pd.read_csv("/content/Entire.csv")
data.head()
# Out:
#                Date     Open     High      Low    Close  Volume
# 0  2020-12-02 09:53  1.20584  1.20586  1.20577  1.20583     263
# 1  2020-12-02 09:54  1.20583  1.20586  1.20577  1.20577     230
# 2  2020-12-02 09:55  1.20575  1.20589  1.20569  1.20586     268
# 3  2020-12-02 10:00  1.20536  1.20564  1.20530  1.20552     298
# 4  2020-12-02 10:01  1.20551  1.20563  1.20525  1.20542     481

# %% [markdown]
# # Data Analysis

# %%
data["Date"] =  [datetime.strptime(a, '%Y-%m-%d %H:%M') for a in data.Date]
data = data.sort_values(by = "Date").reset_index()
data = data.drop("index", axis = 1)
data["date"] =  [a.date() for a in data.Date]

# %%
data.head()
# Out:
#                  Date     Open     High      Low    Close   Volume        date
# 0 2007-01-01 00:00:00  1.31908  1.31973  1.31872  1.31952   145690  2007-01-01
# 1 2007-01-01 00:00:00  1.31908  1.32095  1.31650  1.32058  1946843  2007-01-01
# 2 2007-01-01 01:00:00  1.31908  1.31964  1.31896  1.31913    24827  2007-01-01
# 3 2007-01-01 01:00:00  1.31908  1.31964  1.31894  1.31915    47067  2007-01-01
# 4 2007-01-01 01:30:00  1.31920  1.31943  1.31894  1.31915    22240  2007-01-01

# %%
data.tail()
# Out:
#                       Date     Open     High      Low    Close  Volume  \
# 940398 2021-01-22 22:55:00  1.21701  1.21717  1.21666  1.21667    2352
# 940399 2021-01-22 22:56:00  1.21709  1.21712  1.21706  1.21709     564
# 940400 2021-01-22 22:57:00  1.21709  1.21710  1.21702  1.21706     690
# 940401 2021-01-22 22:58:00  1.21705  1.21709  1.21704  1.21706     473
# 940402 2021-01-22 22:59:00  1.21705  1.21717  1.21666  1.21667     249
#
#               date
# 940398  2021-01-22
# 940399  2021-01-22
# 940400  2021-01-22
# 940401  2021-01-22
# 940402  2021-01-22

# %%
date, volume, start, close, ave  = [],[],[],[],[] 
d, o, c, vol = data.date[0] - timedelta(1), 0, 0, 0
for i in range(len(data)):
    if d != data.date[i]:
        d = data.date[i]
        low_time = data.Date[i].time()
        high_time = data.Date[i].time()
        o, c, vol = data.Open[i], data.Close[i], data.Volume[i]
        date.append(d)
        volume.append(vol)
        start.append(o)
        close.append(c)
        ave.append((o+c)/2)
        
    if low_time > data.Date[i].time():
        low_time = data.Date[i].time()
        o = data.Open[i]
        
    if high_time < data.Date[i].time():
        high_time = data.Date[i].time()
        c = data.Close[i]
        
    if vol != data.Volume[i]:
        vol += data.Volume[i]

# %%
new_data = pd.DataFrame({ 
    'date' : date,
    'volume' : volume,
    'open' : start,
    'close': close,
    'ave' : ave })
print(len(new_data))
new_data.head()
# Out:
# 4398
#          date  volume     open    close       ave
# 0  2007-01-01  145690  1.31908  1.31952  1.319300
# 1  2007-01-02   25112  1.32033  1.32106  1.320695
# 2  2007-01-03   24481  1.32762  1.32710  1.327360
# 3  2007-01-04   23233  1.31626  1.31683  1.316545
# 4  2007-01-05   24544  1.30893  1.30845  1.308690

# %%
plt.figure(figsize = (20,6))
sns.lineplot(data=new_data, x="date", y="open")

# %%
plt.figure(figsize = (20,6))
sns.lineplot(data=new_data, x="date", y="close")

# %%
plt.figure(figsize = (20,6))
sns.lineplot(data=new_data, x="date", y="ave")

# %% [markdown]
# # Training and test set Preparation

# %%
ave = [a*100 for a in ave]

# %%
a = 120

# %%
X_data, y_data = [], []
for i in range(a,len(ave)):
    X_data.append( ave[i-a:i] )
    y_data.append( ave[i] )

len(X_data)
# Out:
# 4278

# %%
X_train, X_val, X_test = X_data[:3000], X_data[3000:3350], X_data[3350:]
y_train, y_val, y_test = y_data[:3000], y_data[3000:3350], y_data[3350:]

# %%
def arraying(s):
    return np.array(s)

def shapeshift(s):
    s = arraying(s)
    return np.reshape(s, (s.shape[0], s.shape[1], 1))

X_train, X_val, X_test = shapeshift(X_train), shapeshift(X_val), shapeshift(X_test)
y_train, y_val, y_test = arraying(y_train), arraying(y_val), arraying(y_test)

# %%
X_train.shape
# Out:
# (3000, 120, 1)

# %% [markdown]
# # Building RNN model (LSTM)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras import layers

# %%
model = Sequential([layers.Input((a,1)),
                    layers.LSTM(64),
                    layers.Dense(32, activation = "relu"),
                    layers.Dense(32, activation = "relu"),
                    layers.Dense(1)
                   ])

model.compile(loss="mse", optimizer = "Adam", metrics = ["mean_absolute_error"])

# %%
model.fit(X_train,y_train, validation_data = (X_val, y_val), epochs = 30)
# Out:
# Epoch 1/30
# 94/94 [==============================] - 8s 66ms/step - loss: 14789.0479 - mean_absolute_error: 120.3831 - val_loss: 5072.8184 - val_mean_absolute_error: 70.9905
# Epoch 2/30
# 94/94 [==============================] - 7s 72ms/step - loss: 1745.8823 - mean_absolute_error: 30.8469 - val_loss: 368.6250 - val_mean_absolute_error: 18.3477
# Epoch 3/30
# 94/94 [==============================] - 6s 61ms/step - loss: 155.4852 - mean_absolute_error: 9.8269 - val_loss: 307.4869 - val_mean_absolute_error: 16.6818
# Epoch 4/30
# 94/94 [==============================] - 6s 60ms/step - loss: 92.8024 - mean_absolute_error: 7.4887 - val_loss: 28.7963 - val_mean_absolute_error: 4.6931
# Epoch 5/30
# 94/94 [==============================] - 6s 60ms/step - loss: 12.9867 - mean_absolute_error: 2.4239 - val_loss: 2.6530 - val_mean_absolute_error: 1.4216
# Epoch 6/30
# 94/94 [==============================] - 6s 60ms/step - loss: 3.4950 - mean_absolute_error: 1.2834 - val_loss: 2.8250 - val_mean_absolute_error: 1.4326
# Epoch 7/30
# 94/94 [==============================] - 6s 60ms/step - loss: 2.1156 - mean_absolute_error: 1.0335 - val_loss: 3.1606 - val_mean_absolute_error: 1.5200
# Epoch 8/30
# 94/94 [==============================] - 6s 60ms/step - loss: 1.5612 - mean_absolute_error: 0.9056 - val_loss: 1.7489 - val_mean_absolute_error: 1.1270
# Epoch 9/30
# 94/94 [==============================] - 6s 59ms/step - loss: 1.2391 - mean_absolute_error: 0.8208 - val_loss: 0.7563 - val_mean_absolute_error: 0.6995
# Epoch 10/30
# 94/94 [==============================] - 6s 60ms/step - loss: 1.0442 - mean_absolute_error: 0.7476 - val_loss: 0.6204 - val_mean_absolute_error: 0.6354
# Epoch 11/30
# 94/94 [==============================] - 6s 59ms/step - loss: 0.9439 - mean_absolute_error: 0.7178 - val_loss: 0.4264 - val_mean_absolute_error: 0.5107
# Epoch 12/30
# 94/94 [==============================] - 6s 59ms/step - loss: 0.8522 - mean_absolute_error: 0.6824 - val_loss: 0.2874 - val_mean_absolute_error: 0.4141
# Epoch 13/30
# 94/94 [==============================] - 6s 60ms/step - loss: 0.7793 - mean_absolute_error: 0.6408 - val_loss: 0.3309 - val_mean_absolute_error: 0.4520
# Epoch 14/30
# 94/94 [==============================] - 6s 59ms/step - loss: 0.8461 - mean_absolute_error: 0.6820 - val_loss: 0.3833 - val_mean_absolute_error: 0.4835
# Epoch 15/30
# 94/94 [==============================] - 6s 60ms/step - loss: 0.8143 - mean_absolute_error: 0.6619 - val_loss: 0.2971 - val_mean_absolute_error: 0.4335
# Epoch 16/30
# 94/94 [==============================] - 6s 59ms/step - loss: 0.8219 - mean_absolute_error: 0.6700 - val_loss: 0.3060 - val_mean_absolute_error: 0.4414
# Epoch 17/30
# 94/94 [==============================] - 6s 61ms/step - loss: 0.7962 - mean_absolute_error: 0.6592 - val_loss: 0.4484 - val_mean_absolute_error: 0.5311
# Epoch 18/30
# 94/94 [==============================] - 6s 60ms/step - loss: 0.7757 - mean_absolute_error: 0.6430 - val_loss: 0.2585 - val_mean_absolute_error: 0.3969
# Epoch 19/30
# 94/94 [==============================] - 6s 63ms/step - loss: 0.8348 - mean_absolute_error: 0.6827 - val_loss: 0.2732 - val_mean_absolute_error: 0.4160
# Epoch 20/30
# 94/94 [==============================] - 6s 67ms/step - loss: 0.7046 - mean_absolute_error: 0.6063 - val_loss: 0.2561 - val_mean_absolute_error: 0.3840
# Epoch 21/30
# 94/94 [==============================] - 6s 59ms/step - loss: 0.7113 - mean_absolute_error: 0.6084 - val_loss: 0.2835 - val_mean_absolute_error: 0.4219
# Epoch 22/30
# 94/94 [==============================] - 6s 61ms/step - loss: 0.7766 - mean_absolute_error: 0.6528 - val_loss: 0.4075 - val_mean_absolute_error: 0.5331
# Epoch 23/30
# 94/94 [==============================] - 6s 59ms/step - loss: 0.7684 - mean_absolute_error: 0.6382 - val_loss: 0.3295 - val_mean_absolute_error: 0.4367
# Epoch 24/30
# 94/94 [==============================] - 6s 60ms/step - loss: 0.6778 - mean_absolute_error: 0.5900 - val_loss: 0.2596 - val_mean_absolute_error: 0.4018
# Epoch 25/30
# 94/94 [==============================] - 6s 60ms/step - loss: 0.7316 - mean_absolute_error: 0.6282 - val_loss: 0.3147 - val_mean_absolute_error: 0.4558
# Epoch 26/30
# 94/94 [==============================] - 6s 59ms/step - loss: 0.7480 - mean_absolute_error: 0.6433 - val_loss: 0.2891 - val_mean_absolute_error: 0.4346
# Epoch 27/30
# 94/94 [==============================] - 6s 59ms/step - loss: 0.7927 - mean_absolute_error: 0.6566 - val_loss: 0.2790 - val_mean_absolute_error: 0.3967
# Epoch 28/30
# 94/94 [==============================] - 6s 60ms/step - loss: 0.7655 - mean_absolute_error: 0.6450 - val_loss: 0.3589 - val_mean_absolute_error: 0.4958
# Epoch 29/30
# 94/94 [==============================] - 6s 60ms/step - loss: 0.7049 - mean_absolute_error: 0.6123 - val_loss: 0.7738 - val_mean_absolute_error: 0.7463
# Epoch 30/30
# 94/94 [==============================] - 6s 59ms/step - loss: 0.7464 - mean_absolute_error: 0.6341 - val_loss: 0.2274 - val_mean_absolute_error: 0.3610

# %% [markdown]
# # Train Set Results

# %%
y_train_pred = model.predict(X_train)

a, b = 200, 100

plt.figure(figsize = (15,6))
plt.plot(date[b:a], y_train_pred[b:a])
plt.plot(date[b:a], y_train[b:a])
plt.legend(["train preds", "acual vals"])

# %%
plt.figure(figsize = (15,6))
plt.plot(date[:3000], y_train_pred)
plt.plot(date[:3000], y_train)
plt.legend(["train preds", "acual vals"])

# %%
from sklearn.metrics import mean_absolute_error as mae
mae(y_train,y_train_pred)/100
# Out:
# 0.005862314449869792

# %% [markdown]
# # Test set predictions

# %%
y_pred = model.predict(X_test)

a, b = 200, 100

plt.figure(figsize = (15,6))
plt.plot(date[b:a], y_pred[b:a])
plt.plot(date[b:a], y_test[b:a])
plt.legend(["train preds", "acual vals"])

# %%
plt.figure(figsize = (15,6))
plt.plot(date[:928], y_pred)
plt.plot(date[:928], y_test)
plt.legend(["test preds", "acual vals"])

# %%
from sklearn.metrics import mean_absolute_error as mae
mae(y_test,y_pred)/100
# Out:
# 0.003001482242058059
