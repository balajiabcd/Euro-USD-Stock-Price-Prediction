# %% [markdown]
# <a href="https://colab.research.google.com/github/balajiabcd/Euro-USD-Stock-Price-Prediction/blob/main/euro_and_usd_stock_prediction02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Libraries

# %%
import numpy as np
import pandas as pd
from datetime import datetime,timedelta

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
data = pd.read_csv("/content/Entire.csv")
data.head()
# Out:
#                Date     Open     High      Low    Close  Volume
# 0  2020-12-02 09:53  1.20584  1.20586  1.20577  1.20583     263
# 1  2020-12-02 09:54  1.20583  1.20586  1.20577  1.20577     230
# 2  2020-12-02 09:55  1.20575  1.20589  1.20569  1.20586     268
# 3  2020-12-02 10:00  1.20536  1.20564  1.20530  1.20552     298
# 4  2020-12-02 10:01  1.20551  1.20563  1.20525  1.20542     481

# %% [markdown]
# # Data Analysis

# %%
data["Date"] =  [datetime.strptime(a, '%Y-%m-%d %H:%M') for a in data.Date]
data = data.sort_values(by = "Date").reset_index()
data = data.drop("index", axis = 1)
data["date"] =  [a.date() for a in data.Date]

# %%
data.head()
# Out:
#                  Date     Open     High      Low    Close   Volume        date
# 0 2007-01-01 00:00:00  1.31908  1.31973  1.31872  1.31952   145690  2007-01-01
# 1 2007-01-01 00:00:00  1.31908  1.32095  1.31650  1.32058  1946843  2007-01-01
# 2 2007-01-01 01:00:00  1.31908  1.31964  1.31896  1.31913    24827  2007-01-01
# 3 2007-01-01 01:00:00  1.31908  1.31964  1.31894  1.31915    47067  2007-01-01
# 4 2007-01-01 01:30:00  1.31920  1.31943  1.31894  1.31915    22240  2007-01-01

# %%
data.tail()
# Out:
#                       Date     Open     High      Low    Close  Volume  \
# 940398 2021-01-22 22:55:00  1.21701  1.21717  1.21666  1.21667    2352
# 940399 2021-01-22 22:56:00  1.21709  1.21712  1.21706  1.21709     564
# 940400 2021-01-22 22:57:00  1.21709  1.21710  1.21702  1.21706     690
# 940401 2021-01-22 22:58:00  1.21705  1.21709  1.21704  1.21706     473
# 940402 2021-01-22 22:59:00  1.21705  1.21717  1.21666  1.21667     249
#
#               date
# 940398  2021-01-22
# 940399  2021-01-22
# 940400  2021-01-22
# 940401  2021-01-22
# 940402  2021-01-22

# %%
date, volume, start, close, ave  = [],[],[],[],[] 
d, o, c, vol = data.date[0] - timedelta(1), 0, 0, 0
for i in range(len(data)):
    if d != data.date[i]:
        d = data.date[i]
        low_time = data.Date[i].time()
        high_time = data.Date[i].time()
        o, c, vol = data.Open[i], data.Close[i], data.Volume[i]
        date.append(d)
        volume.append(vol)
        start.append(o)
        close.append(c)
        ave.append((o+c)/2)
        
    if low_time > data.Date[i].time():
        low_time = data.Date[i].time()
        o = data.Open[i]
        
    if high_time < data.Date[i].time():
        high_time = data.Date[i].time()
        c = data.Close[i]
        
    if vol != data.Volume[i]:
        vol += data.Volume[i]

# %%
new_data = pd.DataFrame({ 
    'date' : date,
    'volume' : volume,
    'open' : start,
    'close': close,
    'ave' : ave })
print(len(new_data))
new_data.head()
# Out:
# 4398
#          date  volume     open    close       ave
# 0  2007-01-01  145690  1.31908  1.31952  1.319300
# 1  2007-01-02   25112  1.32033  1.32106  1.320695
# 2  2007-01-03   24481  1.32762  1.32710  1.327360
# 3  2007-01-04   23233  1.31626  1.31683  1.316545
# 4  2007-01-05   24544  1.30893  1.30845  1.308690

# %%
plt.figure(figsize = (20,6))
sns.lineplot(data=new_data, x="date", y="open")

# %%
plt.figure(figsize = (20,6))
sns.lineplot(data=new_data, x="date", y="close")

# %%
plt.figure(figsize = (20,6))
sns.lineplot(data=new_data, x="date", y="ave")

# %% [markdown]
# # Training and test set Preparation

# %%
ave = [a*100 for a in ave]

# %%
a = 10

# %%
X_data, y_data = [], []
for i in range(a,len(ave)):
    X_data.append( ave[i-a:i] )
    y_data.append( ave[i] )

len(X_data)
# Out:
# 4388

# %%
X_train, X_val, X_test = X_data[:3000], X_data[3000:3350], X_data[3350:]
y_train, y_val, y_test = y_data[:3000], y_data[3000:3350], y_data[3350:]

# %%
def arraying(s):
    return np.array(s)

def shapeshift(s):
    s = arraying(s)
    return np.reshape(s, (s.shape[0], s.shape[1], 1))

X_train, X_val, X_test = shapeshift(X_train), shapeshift(X_val), shapeshift(X_test)
y_train, y_val, y_test = arraying(y_train), arraying(y_val), arraying(y_test)

# %%
X_train.shape
# Out:
# (3000, 10, 1)

# %% [markdown]
# # Building RNN model (LSTM)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras import layers

# %%
model = Sequential([layers.Input((a,1)),
                    layers.LSTM(64),
                    layers.Dense(32, activation = "relu"),
                    layers.Dense(32, activation = "relu"),
                    layers.Dense(1)
                   ])

model.compile(loss="mse", optimizer = "Adam", metrics = ["mean_absolute_error"])

# %%
model.fit(X_train,y_train, validation_data = (X_val, y_val), epochs = 30)
# Out:
# Epoch 1/30
# 94/94 [==============================] - 3s 15ms/step - loss: 15203.8223 - mean_absolute_error: 122.1693 - val_loss: 4708.9204 - val_mean_absolute_error: 68.4733
# Epoch 2/30
# 94/94 [==============================] - 1s 9ms/step - loss: 1578.0438 - mean_absolute_error: 28.0191 - val_loss: 458.4213 - val_mean_absolute_error: 20.9525
# Epoch 3/30
# 94/94 [==============================] - 1s 9ms/step - loss: 142.3948 - mean_absolute_error: 9.1702 - val_loss: 408.6670 - val_mean_absolute_error: 19.7996
# Epoch 4/30
# 94/94 [==============================] - 1s 9ms/step - loss: 58.6461 - mean_absolute_error: 5.3687 - val_loss: 2.6682 - val_mean_absolute_error: 1.3338
# Epoch 5/30
# 94/94 [==============================] - 1s 9ms/step - loss: 4.7961 - mean_absolute_error: 1.4131 - val_loss: 2.0690 - val_mean_absolute_error: 1.2545
# Epoch 6/30
# 94/94 [==============================] - 1s 8ms/step - loss: 2.2647 - mean_absolute_error: 1.0255 - val_loss: 0.3429 - val_mean_absolute_error: 0.4600
# Epoch 7/30
# 94/94 [==============================] - 1s 9ms/step - loss: 1.5425 - mean_absolute_error: 0.8811 - val_loss: 0.5716 - val_mean_absolute_error: 0.6503
# Epoch 8/30
# 94/94 [==============================] - 1s 9ms/step - loss: 1.2028 - mean_absolute_error: 0.7809 - val_loss: 0.2599 - val_mean_absolute_error: 0.3873
# Epoch 9/30
# 94/94 [==============================] - 1s 9ms/step - loss: 1.0941 - mean_absolute_error: 0.7587 - val_loss: 0.2365 - val_mean_absolute_error: 0.3561
# Epoch 10/30
# 94/94 [==============================] - 1s 9ms/step - loss: 0.9641 - mean_absolute_error: 0.7179 - val_loss: 0.3394 - val_mean_absolute_error: 0.4741
# Epoch 11/30
# 94/94 [==============================] - 1s 9ms/step - loss: 0.9208 - mean_absolute_error: 0.7058 - val_loss: 0.2382 - val_mean_absolute_error: 0.3614
# Epoch 12/30
# 94/94 [==============================] - 1s 9ms/step - loss: 0.9087 - mean_absolute_error: 0.6980 - val_loss: 0.2650 - val_mean_absolute_error: 0.4000
# Epoch 13/30
# 94/94 [==============================] - 1s 8ms/step - loss: 0.8289 - mean_absolute_error: 0.6615 - val_loss: 0.3478 - val_mean_absolute_error: 0.4795
# Epoch 14/30
# 94/94 [==============================] - 1s 9ms/step - loss: 0.8508 - mean_absolute_error: 0.6763 - val_loss: 0.3180 - val_mean_absolute_error: 0.4322
# Epoch 15/30
# 94/94 [==============================] - 1s 9ms/step - loss: 0.8653 - mean_absolute_error: 0.6928 - val_loss: 0.2447 - val_mean_absolute_error: 0.3650
# Epoch 16/30
# 94/94 [==============================] - 1s 8ms/step - loss: 0.8192 - mean_absolute_error: 0.6693 - val_loss: 0.3276 - val_mean_absolute_error: 0.4665
# Epoch 17/30
# 94/94 [==============================] - 1s 8ms/step - loss: 0.8252 - mean_absolute_error: 0.6759 - val_loss: 0.2564 - val_mean_absolute_error: 0.3773
# Epoch 18/30
# 94/94 [==============================] - 1s 9ms/step - loss: 0.8746 - mean_absolute_error: 0.7096 - val_loss: 0.2974 - val_mean_absolute_error: 0.4351
# Epoch 19/30
# 94/94 [==============================] - 1s 9ms/step - loss: 0.8258 - mean_absolute_error: 0.6761 - val_loss: 0.2342 - val_mean_absolute_error: 0.3529
# Epoch 20/30
# 94/94 [==============================] - 1s 9ms/step - loss: 0.8078 - mean_absolute_error: 0.6556 - val_loss: 0.7066 - val_mean_absolute_error: 0.7128
# Epoch 21/30
# 94/94 [==============================] - 1s 8ms/step - loss: 0.7693 - mean_absolute_error: 0.6400 - val_loss: 0.2552 - val_mean_absolute_error: 0.3846
# Epoch 22/30
# 94/94 [==============================] - 1s 8ms/step - loss: 0.7784 - mean_absolute_error: 0.6452 - val_loss: 0.2632 - val_mean_absolute_error: 0.3867
# Epoch 23/30
# 94/94 [==============================] - 1s 8ms/step - loss: 0.7101 - mean_absolute_error: 0.6053 - val_loss: 0.2684 - val_mean_absolute_error: 0.3885
# Epoch 24/30
# 94/94 [==============================] - 1s 9ms/step - loss: 0.7430 - mean_absolute_error: 0.6255 - val_loss: 0.4773 - val_mean_absolute_error: 0.5602
# Epoch 25/30
# 94/94 [==============================] - 1s 9ms/step - loss: 0.7976 - mean_absolute_error: 0.6647 - val_loss: 0.2932 - val_mean_absolute_error: 0.4350
# Epoch 26/30
# 94/94 [==============================] - 1s 8ms/step - loss: 0.7530 - mean_absolute_error: 0.6356 - val_loss: 0.3068 - val_mean_absolute_error: 0.4469
# Epoch 27/30
# 94/94 [==============================] - 1s 9ms/step - loss: 0.7504 - mean_absolute_error: 0.6406 - val_loss: 0.7739 - val_mean_absolute_error: 0.7843
# Epoch 28/30
# 94/94 [==============================] - 1s 9ms/step - loss: 0.7201 - mean_absolute_error: 0.6144 - val_loss: 0.2781 - val_mean_absolute_error: 0.4105
# Epoch 29/30
# 94/94 [==============================] - 1s 9ms/step - loss: 0.6696 - mean_absolute_error: 0.5793 - val_loss: 0.2432 - val_mean_absolute_error: 0.3714
# Epoch 30/30
# 94/94 [==============================] - 1s 9ms/step - loss: 0.7003 - mean_absolute_error: 0.6085 - val_loss: 0.3333 - val_mean_absolute_error: 0.4432

# %% [markdown]
# # Train Set Results

# %%
y_train_pred = model.predict(X_train)

a, b = 200, 100

plt.figure(figsize = (15,6))
plt.plot(date[b:a], y_train_pred[b:a])
plt.plot(date[b:a], y_train[b:a])
plt.legend(["train preds", "acual vals"])

# %%
plt.figure(figsize = (15,6))
plt.plot(date[:3000], y_train_pred)
plt.plot(date[:3000], y_train)
plt.legend(["train preds", "acual vals"])

# %%
from sklearn.metrics import mean_absolute_error as mae
mae(y_train,y_train_pred)/100
# Out:
# 0.007628218080037433

# %% [markdown]
# # Test set predictions

# %%
y_pred = model.predict(X_test)

a, b = 200, 100

plt.figure(figsize = (15,6))
plt.plot(date[b:a], y_pred[b:a])
plt.plot(date[b:a], y_test[b:a])
plt.legend(["train preds", "acual vals"])

# %%
plt.figure(figsize = (15,6))
plt.plot(date[:1038], y_pred)
plt.plot(date[:1038], y_test)
plt.legend(["test preds", "acual vals"])

# %%
from sklearn.metrics import mean_absolute_error as mae
mae(y_test,y_pred)/100
# Out:
# 0.004783012508914189
