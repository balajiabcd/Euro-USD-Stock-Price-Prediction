# %% [markdown]
# <a href="https://colab.research.google.com/github/balajiabcd/Euro-USD-Stock-Price-Prediction/blob/main/euro_and_usd_stock_prediction04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Libraries

# %%
import numpy as np
import pandas as pd
from datetime import datetime,timedelta

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
data = pd.read_csv("/content/Entire.csv")
data.head()
# Out:
#                Date     Open     High      Low    Close  Volume
# 0  2020-12-02 09:53  1.20584  1.20586  1.20577  1.20583     263
# 1  2020-12-02 09:54  1.20583  1.20586  1.20577  1.20577     230
# 2  2020-12-02 09:55  1.20575  1.20589  1.20569  1.20586     268
# 3  2020-12-02 10:00  1.20536  1.20564  1.20530  1.20552     298
# 4  2020-12-02 10:01  1.20551  1.20563  1.20525  1.20542     481

# %% [markdown]
# # Data Analysis

# %%
data["Date"] =  [datetime.strptime(a, '%Y-%m-%d %H:%M') for a in data.Date]
data = data.sort_values(by = "Date").reset_index()
data = data.drop("index", axis = 1)
data["date"] =  [a.date() for a in data.Date]

# %%
data.head()
# Out:
#                  Date     Open     High      Low    Close   Volume        date
# 0 2007-01-01 00:00:00  1.31908  1.31973  1.31872  1.31952   145690  2007-01-01
# 1 2007-01-01 00:00:00  1.31908  1.32095  1.31650  1.32058  1946843  2007-01-01
# 2 2007-01-01 01:00:00  1.31908  1.31964  1.31896  1.31913    24827  2007-01-01
# 3 2007-01-01 01:00:00  1.31908  1.31964  1.31894  1.31915    47067  2007-01-01
# 4 2007-01-01 01:30:00  1.31920  1.31943  1.31894  1.31915    22240  2007-01-01

# %%
data.tail()
# Out:
#                       Date     Open     High      Low    Close  Volume  \
# 940398 2021-01-22 22:55:00  1.21701  1.21717  1.21666  1.21667    2352
# 940399 2021-01-22 22:56:00  1.21709  1.21712  1.21706  1.21709     564
# 940400 2021-01-22 22:57:00  1.21709  1.21710  1.21702  1.21706     690
# 940401 2021-01-22 22:58:00  1.21705  1.21709  1.21704  1.21706     473
# 940402 2021-01-22 22:59:00  1.21705  1.21717  1.21666  1.21667     249
#
#               date
# 940398  2021-01-22
# 940399  2021-01-22
# 940400  2021-01-22
# 940401  2021-01-22
# 940402  2021-01-22

# %%
date, volume, start, close, ave  = [],[],[],[],[] 
d, o, c, vol = data.date[0] - timedelta(1), 0, 0, 0
for i in range(len(data)):
    if d != data.date[i]:
        d = data.date[i]
        low_time = data.Date[i].time()
        high_time = data.Date[i].time()
        o, c, vol = data.Open[i], data.Close[i], data.Volume[i]
        date.append(d)
        volume.append(vol)
        start.append(o)
        close.append(c)
        ave.append((o+c)/2)
        
    if low_time > data.Date[i].time():
        low_time = data.Date[i].time()
        o = data.Open[i]
        
    if high_time < data.Date[i].time():
        high_time = data.Date[i].time()
        c = data.Close[i]
        
    if vol != data.Volume[i]:
        vol += data.Volume[i]

# %%
new_data = pd.DataFrame({ 
    'date' : date,
    'volume' : volume,
    'open' : start,
    'close': close,
    'ave' : ave })
print(len(new_data))
new_data.head()
# Out:
# 4398
#          date  volume     open    close       ave
# 0  2007-01-01  145690  1.31908  1.31952  1.319300
# 1  2007-01-02   25112  1.32033  1.32106  1.320695
# 2  2007-01-03   24481  1.32762  1.32710  1.327360
# 3  2007-01-04   23233  1.31626  1.31683  1.316545
# 4  2007-01-05   24544  1.30893  1.30845  1.308690

# %%
plt.figure(figsize = (20,6))
sns.lineplot(data=new_data, x="date", y="open")

# %%
plt.figure(figsize = (20,6))
sns.lineplot(data=new_data, x="date", y="close")

# %%
plt.figure(figsize = (20,6))
sns.lineplot(data=new_data, x="date", y="ave")

# %% [markdown]
# # Training and test set Preparation

# %%
ave = [a*100 for a in ave]

# %%
a = 3

# %%
X_data, y_data = [], []
for i in range(a,len(ave)):
    X_data.append( ave[i-a:i] )
    y_data.append( ave[i] )

len(X_data)
# Out:
# 4395

# %%
X_train, X_val, X_test = X_data[:3000], X_data[3000:3350], X_data[3350:]
y_train, y_val, y_test = y_data[:3000], y_data[3000:3350], y_data[3350:]

# %%
def arraying(s):
    return np.array(s)

def shapeshift(s):
    s = arraying(s)
    return np.reshape(s, (s.shape[0], s.shape[1], 1))

X_train, X_val, X_test = shapeshift(X_train), shapeshift(X_val), shapeshift(X_test)
y_train, y_val, y_test = arraying(y_train), arraying(y_val), arraying(y_test)

# %%
X_train.shape
# Out:
# (3000, 3, 1)

# %% [markdown]
# # Building RNN model (LSTM)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras import layers

# %%
model = Sequential([layers.Input((a,1)),
                    layers.LSTM(64),
                    layers.Dense(32, activation = "relu"),
                    layers.Dense(32, activation = "relu"),
                    layers.Dense(1)
                   ])

model.compile(loss="mse", optimizer = "Adam", metrics = ["mean_absolute_error"])

# %%
model.fit(X_train,y_train, validation_data = (X_val, y_val), epochs = 30)
# Out:
# Epoch 1/30
# 94/94 [==============================] - 3s 10ms/step - loss: 15283.3838 - mean_absolute_error: 122.4784 - val_loss: 4250.4058 - val_mean_absolute_error: 65.0481
# Epoch 2/30
# 94/94 [==============================] - 0s 5ms/step - loss: 1324.2023 - mean_absolute_error: 25.1776 - val_loss: 443.0854 - val_mean_absolute_error: 20.6475
# Epoch 3/30
# 94/94 [==============================] - 1s 6ms/step - loss: 106.4303 - mean_absolute_error: 7.8484 - val_loss: 121.8857 - val_mean_absolute_error: 10.8888
# Epoch 4/30
# 94/94 [==============================] - 0s 5ms/step - loss: 15.4501 - mean_absolute_error: 2.5091 - val_loss: 0.2978 - val_mean_absolute_error: 0.4256
# Epoch 5/30
# 94/94 [==============================] - 0s 5ms/step - loss: 2.1050 - mean_absolute_error: 0.9959 - val_loss: 0.5539 - val_mean_absolute_error: 0.5989
# Epoch 6/30
# 94/94 [==============================] - 1s 6ms/step - loss: 1.1807 - mean_absolute_error: 0.7677 - val_loss: 0.5776 - val_mean_absolute_error: 0.6169
# Epoch 7/30
# 94/94 [==============================] - 1s 5ms/step - loss: 0.9908 - mean_absolute_error: 0.7177 - val_loss: 0.4134 - val_mean_absolute_error: 0.5178
# Epoch 8/30
# 94/94 [==============================] - 0s 5ms/step - loss: 1.0012 - mean_absolute_error: 0.7471 - val_loss: 0.3787 - val_mean_absolute_error: 0.4964
# Epoch 9/30
# 94/94 [==============================] - 1s 6ms/step - loss: 0.9012 - mean_absolute_error: 0.7071 - val_loss: 0.6618 - val_mean_absolute_error: 0.6845
# Epoch 10/30
# 94/94 [==============================] - 0s 5ms/step - loss: 0.7866 - mean_absolute_error: 0.6424 - val_loss: 0.2652 - val_mean_absolute_error: 0.4003
# Epoch 11/30
# 94/94 [==============================] - 1s 5ms/step - loss: 0.9241 - mean_absolute_error: 0.7228 - val_loss: 0.2898 - val_mean_absolute_error: 0.4130
# Epoch 12/30
# 94/94 [==============================] - 1s 5ms/step - loss: 0.7523 - mean_absolute_error: 0.6287 - val_loss: 0.2732 - val_mean_absolute_error: 0.4087
# Epoch 13/30
# 94/94 [==============================] - 0s 5ms/step - loss: 0.8357 - mean_absolute_error: 0.6776 - val_loss: 0.2876 - val_mean_absolute_error: 0.4239
# Epoch 14/30
# 94/94 [==============================] - 0s 5ms/step - loss: 0.7536 - mean_absolute_error: 0.6308 - val_loss: 0.7806 - val_mean_absolute_error: 0.7570
# Epoch 15/30
# 94/94 [==============================] - 0s 5ms/step - loss: 0.8383 - mean_absolute_error: 0.6901 - val_loss: 0.2912 - val_mean_absolute_error: 0.4076
# Epoch 16/30
# 94/94 [==============================] - 0s 5ms/step - loss: 0.8048 - mean_absolute_error: 0.6726 - val_loss: 0.2316 - val_mean_absolute_error: 0.3612
# Epoch 17/30
# 94/94 [==============================] - 0s 5ms/step - loss: 0.8590 - mean_absolute_error: 0.6848 - val_loss: 0.2359 - val_mean_absolute_error: 0.3561
# Epoch 18/30
# 94/94 [==============================] - 0s 5ms/step - loss: 0.7689 - mean_absolute_error: 0.6398 - val_loss: 0.2410 - val_mean_absolute_error: 0.3749
# Epoch 19/30
# 94/94 [==============================] - 0s 5ms/step - loss: 0.7841 - mean_absolute_error: 0.6510 - val_loss: 0.3058 - val_mean_absolute_error: 0.4491
# Epoch 20/30
# 94/94 [==============================] - 0s 5ms/step - loss: 0.7760 - mean_absolute_error: 0.6494 - val_loss: 0.2264 - val_mean_absolute_error: 0.3542
# Epoch 21/30
# 94/94 [==============================] - 0s 5ms/step - loss: 0.8553 - mean_absolute_error: 0.6985 - val_loss: 0.4665 - val_mean_absolute_error: 0.5892
# Epoch 22/30
# 94/94 [==============================] - 0s 5ms/step - loss: 0.8123 - mean_absolute_error: 0.6742 - val_loss: 0.3378 - val_mean_absolute_error: 0.4514
# Epoch 23/30
# 94/94 [==============================] - 0s 5ms/step - loss: 0.8685 - mean_absolute_error: 0.7126 - val_loss: 0.6364 - val_mean_absolute_error: 0.6750
# Epoch 24/30
# 94/94 [==============================] - 0s 5ms/step - loss: 0.9266 - mean_absolute_error: 0.7366 - val_loss: 0.3729 - val_mean_absolute_error: 0.4790
# Epoch 25/30
# 94/94 [==============================] - 1s 5ms/step - loss: 0.6816 - mean_absolute_error: 0.5994 - val_loss: 0.2822 - val_mean_absolute_error: 0.4004
# Epoch 26/30
# 94/94 [==============================] - 1s 5ms/step - loss: 0.7327 - mean_absolute_error: 0.6254 - val_loss: 0.3679 - val_mean_absolute_error: 0.4756
# Epoch 27/30
# 94/94 [==============================] - 0s 5ms/step - loss: 0.7055 - mean_absolute_error: 0.6132 - val_loss: 0.4161 - val_mean_absolute_error: 0.5157
# Epoch 28/30
# 94/94 [==============================] - 0s 5ms/step - loss: 0.7446 - mean_absolute_error: 0.6363 - val_loss: 0.2284 - val_mean_absolute_error: 0.3479
# Epoch 29/30
# 94/94 [==============================] - 1s 5ms/step - loss: 0.7488 - mean_absolute_error: 0.6381 - val_loss: 0.2534 - val_mean_absolute_error: 0.3942
# Epoch 30/30
# 94/94 [==============================] - 1s 5ms/step - loss: 0.7421 - mean_absolute_error: 0.6341 - val_loss: 0.2185 - val_mean_absolute_error: 0.3393

# %% [markdown]
# # Train Set Results

# %%
y_train_pred = model.predict(X_train)

a, b = 200, 100

plt.figure(figsize = (15,6))
plt.plot(date[b:a], y_train_pred[b:a])
plt.plot(date[b:a], y_train[b:a])
plt.legend(["train preds", "acual vals"])

# %%
plt.figure(figsize = (15,6))
plt.plot(date[:3000], y_train_pred)
plt.plot(date[:3000], y_train)
plt.legend(["train preds", "acual vals"])

# %%
from sklearn.metrics import mean_absolute_error as mae
mae(y_train,y_train_pred)/100
# Out:
# 0.005380390332641604

# %% [markdown]
# # Test set predictions

# %%
y_pred = model.predict(X_test)

a, b = 200, 100

plt.figure(figsize = (15,6))
plt.plot(date[b:a], y_pred[b:a])
plt.plot(date[b:a], y_test[b:a])
plt.legend(["train preds", "acual vals"])

# %%
plt.figure(figsize = (15,6))
plt.plot(date[:1045], y_pred)
plt.plot(date[:1045], y_test)
plt.legend(["test preds", "acual vals"])

# %%
from sklearn.metrics import mean_absolute_error as mae
mae(y_test,y_pred)/100
# Out:
# 0.0029329524188612026
