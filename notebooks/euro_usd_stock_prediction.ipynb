# %% [markdown]
# <a href="https://colab.research.google.com/github/balajiabcd/Euro-USD-Stock-Price-Prediction/blob/main/euro_and_usd_stock_prediction07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Libraries

# %%
import os

# go up one level
os.chdir("..")

print(os.getcwd())
# Out:
# d:\Github_work\Euro-USD-Stock-Price-Prediction

# %%
import numpy as np
import pandas as pd
from datetime import datetime,timedelta

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
data = pd.read_csv("data/Entire.csv")
data.head()
# Out:
#                Date     Open     High      Low    Close  Volume
# 0  2020-12-02 09:53  1.20584  1.20586  1.20577  1.20583     263
# 1  2020-12-02 09:54  1.20583  1.20586  1.20577  1.20577     230
# 2  2020-12-02 09:55  1.20575  1.20589  1.20569  1.20586     268
# 3  2020-12-02 10:00  1.20536  1.20564  1.20530  1.20552     298
# 4  2020-12-02 10:01  1.20551  1.20563  1.20525  1.20542     481

# %% [markdown]
# # Data Analysis

# %%
data["Date"] =  [datetime.strptime(a, '%Y-%m-%d %H:%M') for a in data.Date]
data = data.sort_values(by = "Date").reset_index()
data = data.drop("index", axis = 1)
data["date"] =  [a.date() for a in data.Date]

# %%
data.head()
# Out:
#                  Date     Open     High      Low    Close   Volume        date
# 0 2007-01-01 00:00:00  1.31908  1.31973  1.31872  1.31952   145690  2007-01-01
# 1 2007-01-01 00:00:00  1.31908  1.32095  1.31650  1.32058  1946843  2007-01-01
# 2 2007-01-01 01:00:00  1.31908  1.31964  1.31896  1.31913    24827  2007-01-01
# 3 2007-01-01 01:00:00  1.31908  1.31964  1.31894  1.31915    47067  2007-01-01
# 4 2007-01-01 01:30:00  1.31920  1.31943  1.31894  1.31915    22240  2007-01-01

# %%
data.date[len(data)-1]
# Out:
# datetime.date(2021, 1, 22)

# %%
data.tail()
# Out:
#                       Date     Open     High      Low    Close  Volume  \
# 940398 2021-01-22 22:55:00  1.21701  1.21717  1.21666  1.21667    2352
# 940399 2021-01-22 22:56:00  1.21709  1.21712  1.21706  1.21709     564
# 940400 2021-01-22 22:57:00  1.21709  1.21710  1.21702  1.21706     690
# 940401 2021-01-22 22:58:00  1.21705  1.21709  1.21704  1.21706     473
# 940402 2021-01-22 22:59:00  1.21705  1.21717  1.21666  1.21667     249
#
#               date
# 940398  2021-01-22
# 940399  2021-01-22
# 940400  2021-01-22
# 940401  2021-01-22
# 940402  2021-01-22

# %%
date, volume, high, low, ave  = [],[],[],[],[] 
d, h, l, vol = data.date[0], 0, 0, 0
for i in range(len(data)+1):

    if i == len(data) or d != data.date[i]:
        date.append(d)
        volume.append(vol)
        high.append(h)
        low.append(l)
        ave.append((h+l)/2)
        if i != len(data):
            d = data.date[i]
            h, l, vol = data.High[i], data.Low[i], data.Volume[i]
    else:
        vol += data.Volume[i]
        if h < data.High[i]:
            h = data.High[i]
        if l < data.Low[i]:
            l = data.Low[i]

# %%
new_data = pd.DataFrame({ 
    'date' : date,
    'volume' : volume,
    'high' : high,
    'low': low,
    'ave' : ave })
print(len(new_data))
new_data.head()
# Out:
# 4398
#          date   volume     high      low      ave
# 0  2007-01-01  7787372  1.32095  1.31959  1.32027
# 1  2007-01-02  8039464  1.32951  1.32795  1.32873
# 2  2007-01-03  8068956  1.32903  1.32809  1.32856
# 3  2007-01-04  8026940  1.31783  1.31699  1.31741
# 4  2007-01-05  7861656  1.31029  1.30929  1.30979

# %%
plt.figure(figsize = (20,6))
sns.lineplot(data=new_data, x="date", y="high")
# Out:
# c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='date', ylabel='high'>

# %%
plt.figure(figsize = (20,6))
sns.lineplot(data=new_data, x="date", y="low")
# Out:
# c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='date', ylabel='low'>

# %%
plt.figure(figsize = (20,6))
sns.lineplot(data=new_data, x="date", y="ave")
# Out:
# c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='date', ylabel='ave'>

# %% [markdown]
# # Training and test set Preparation

# %%
ave = [a*100 for a in ave]

# %%
a = 120

# %%
X_data, y_data = [], []
for i in range(a,len(ave)):
    X_data.append( ave[i-a:i] )
    y_data.append( ave[i] )

len(X_data)
# Out:
# 4278

# %%
X_train, X_val, X_test = X_data[:3000], X_data[3000:3350], X_data[3350:]
y_train, y_val, y_test = y_data[:3000], y_data[3000:3350], y_data[3350:]

# %%
def arraying(s):
    return np.array(s)

def shapeshift(s):
    s = arraying(s)
    return np.reshape(s, (s.shape[0], s.shape[1], 1))

X_train, X_val, X_test = shapeshift(X_train), shapeshift(X_val), shapeshift(X_test)
y_train, y_val, y_test = arraying(y_train), arraying(y_val), arraying(y_test)

# %%
X_train.shape
# Out:
# (3000, 120, 1)

# %% [markdown]
# # Building RNN model (LSTM)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras import layers

# %%
from tensorflow.keras.losses import Huber
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam
    
model = Sequential([layers.Input((a,1)),
                    layers.LSTM(64),
                    layers.Dense(32, activation = "relu"),
                    layers.Dense(32, activation = "relu"),
                    layers.Dense(1)
                   ])

model.compile(
    loss=Huber(delta=1.0),
    optimizer=Adam(learning_rate=1e-3),
    metrics=["mae", "mape", RootMeanSquaredError(name="rmse")]
)

# %%
model.fit(X_train,y_train, validation_data = (X_val, y_val), epochs = 15)
# Out:
# Epoch 1/15
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 6s 36ms/step - loss: 124.0429 - mae: 124.5429 - mape: 94.6496 - rmse: 125.5025 - val_loss: 33.0432 - val_mae: 33.5432 - val_mape: 29.2967 - val_rmse: 34.0659
# Epoch 2/15
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 21.6835 - mae: 22.1771 - mape: 16.8125 - rmse: 27.2463 - val_loss: 17.1406 - val_mae: 17.6406 - val_mape: 15.7772 - val_rmse: 18.3946
# Epoch 3/15
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 6.6575 - mae: 7.1390 - mape: 5.5850 - rmse: 9.2563 - val_loss: 1.1218 - val_mae: 1.5442 - val_mape: 1.3200 - val_rmse: 1.8497
# Epoch 4/15
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 1.0413 - mae: 1.4614 - mape: 1.0852 - rmse: 1.9531 - val_loss: 0.3868 - val_mae: 0.7645 - val_mape: 0.6572 - val_rmse: 0.9293
# Epoch 5/15
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.7356 - mae: 1.1413 - mape: 0.8600 - rmse: 1.4785 - val_loss: 0.1254 - val_mae: 0.3929 - val_mape: 0.3451 - val_rmse: 0.5088
# Epoch 6/15
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 0.6368 - mae: 1.0078 - mape: 0.7626 - rmse: 1.4124 - val_loss: 0.1029 - val_mae: 0.3486 - val_mape: 0.3063 - val_rmse: 0.4602
# Epoch 7/15
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.4282 - mae: 0.7871 - mape: 0.5937 - rmse: 1.0511 - val_loss: 0.1457 - val_mae: 0.4426 - val_mape: 0.3912 - val_rmse: 0.5464
# Epoch 8/15
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.3847 - mae: 0.7326 - mape: 0.5546 - rmse: 0.9793 - val_loss: 0.1381 - val_mae: 0.4271 - val_mape: 0.3770 - val_rmse: 0.5321
# Epoch 9/15
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.3417 - mae: 0.6838 - mape: 0.5194 - rmse: 0.9116 - val_loss: 0.2211 - val_mae: 0.5550 - val_mape: 0.4857 - val_rmse: 0.6796
# Epoch 10/15
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.3333 - mae: 0.6780 - mape: 0.5164 - rmse: 0.8953 - val_loss: 0.1060 - val_mae: 0.3591 - val_mape: 0.3168 - val_rmse: 0.4660
# Epoch 11/15
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.3610 - mae: 0.7081 - mape: 0.5382 - rmse: 0.9470 - val_loss: 0.1017 - val_mae: 0.3510 - val_mape: 0.3091 - val_rmse: 0.4566
# Epoch 12/15
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.3027 - mae: 0.6266 - mape: 0.4790 - rmse: 0.8583 - val_loss: 0.1023 - val_mae: 0.3530 - val_mape: 0.3106 - val_rmse: 0.4579
# Epoch 13/15
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.3290 - mae: 0.6727 - mape: 0.5132 - rmse: 0.8963 - val_loss: 0.1064 - val_mae: 0.3623 - val_mape: 0.3196 - val_rmse: 0.4667
# Epoch 14/15
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 0.3528 - mae: 0.7053 - mape: 0.5373 - rmse: 0.9301 - val_loss: 0.1082 - val_mae: 0.3663 - val_mape: 0.3234 - val_rmse: 0.4705
# Epoch 15/15
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.2754 - mae: 0.5960 - mape: 0.4537 - rmse: 0.8125 - val_loss: 0.1633 - val_mae: 0.4711 - val_mape: 0.4184 - val_rmse: 0.5783

# %% [markdown]
# # Train Set Results

# %%
y_train_pred = model.predict(X_train)

a, b = 200, 100

plt.figure(figsize = (15,6))
plt.plot(date[b:a], y_train_pred[b:a])
plt.plot(date[b:a], y_train[b:a])
plt.legend(["train preds", "acual vals"])
# Out:
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step

# %%
plt.figure(figsize = (15,6))
plt.plot(date[:3000], y_train_pred)
plt.plot(date[:3000], y_train)
plt.legend(["train preds", "acual vals"])

# %%
from sklearn.metrics import mean_absolute_error as mae
mae(y_train,y_train_pred)/100
# Out:
# 0.006055932006225584

# %% [markdown]
# # Test set predictions

# %%
y_pred = model.predict(X_test)

a, b = 200, 100

plt.figure(figsize = (15,6))
plt.plot(date[b:a], y_pred[b:a])
plt.plot(date[b:a], y_test[b:a])
plt.legend(["train preds", "acual vals"])
# Out:
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step

# %%
plt.figure(figsize = (15,6))
plt.plot(date[:928], y_pred)
plt.plot(date[:928], y_test)
plt.legend(["test preds", "acual vals"])

# %%
from sklearn.metrics import mean_absolute_error as mae
mae(y_test,y_pred)/100
# Out:
# 0.004477954329786628
