# %% [markdown]
# <a href="https://colab.research.google.com/github/balajiabcd/Euro-USD-Stock-Price-Prediction/blob/main/euro_and_usd_stock_prediction01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Libraries

# %%
import numpy as np
import pandas as pd
from datetime import datetime,timedelta

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
data = pd.read_csv("/content/Entire.csv")
data.head()
# Out:
#                Date     Open     High      Low    Close  Volume
# 0  2020-12-02 09:53  1.20584  1.20586  1.20577  1.20583     263
# 1  2020-12-02 09:54  1.20583  1.20586  1.20577  1.20577     230
# 2  2020-12-02 09:55  1.20575  1.20589  1.20569  1.20586     268
# 3  2020-12-02 10:00  1.20536  1.20564  1.20530  1.20552     298
# 4  2020-12-02 10:01  1.20551  1.20563  1.20525  1.20542     481

# %% [markdown]
# # Data Analysis

# %%
data["Date"] =  [datetime.strptime(a, '%Y-%m-%d %H:%M') for a in data.Date]
data = data.sort_values(by = "Date").reset_index()
data = data.drop("index", axis = 1)
data["date"] =  [a.date() for a in data.Date]

# %%
data.head()
# Out:
#                  Date     Open     High      Low    Close   Volume        date
# 0 2007-01-01 00:00:00  1.31908  1.31973  1.31872  1.31952   145690  2007-01-01
# 1 2007-01-01 00:00:00  1.31908  1.32095  1.31650  1.32058  1946843  2007-01-01
# 2 2007-01-01 01:00:00  1.31908  1.31964  1.31896  1.31913    24827  2007-01-01
# 3 2007-01-01 01:00:00  1.31908  1.31964  1.31894  1.31915    47067  2007-01-01
# 4 2007-01-01 01:30:00  1.31920  1.31943  1.31894  1.31915    22240  2007-01-01

# %%
data.tail()
# Out:
#                       Date     Open     High      Low    Close  Volume  \
# 940398 2021-01-22 22:55:00  1.21701  1.21717  1.21666  1.21667    2352
# 940399 2021-01-22 22:56:00  1.21709  1.21712  1.21706  1.21709     564
# 940400 2021-01-22 22:57:00  1.21709  1.21710  1.21702  1.21706     690
# 940401 2021-01-22 22:58:00  1.21705  1.21709  1.21704  1.21706     473
# 940402 2021-01-22 22:59:00  1.21705  1.21717  1.21666  1.21667     249
#
#               date
# 940398  2021-01-22
# 940399  2021-01-22
# 940400  2021-01-22
# 940401  2021-01-22
# 940402  2021-01-22

# %%
date, volume, start, close, ave  = [],[],[],[],[] 
d, o, c, vol = data.date[0] - timedelta(1), 0, 0, 0
for i in range(len(data)):
    if d != data.date[i]:
        d = data.date[i]
        low_time = data.Date[i].time()
        high_time = data.Date[i].time()
        o, c, vol = data.Open[i], data.Close[i], data.Volume[i]
        date.append(d)
        volume.append(vol)
        start.append(o)
        close.append(c)
        ave.append((o+c)/2)
        
    if low_time > data.Date[i].time():
        low_time = data.Date[i].time()
        o = data.Open[i]
        
    if high_time < data.Date[i].time():
        high_time = data.Date[i].time()
        c = data.Close[i]
        
    if vol != data.Volume[i]:
        vol += data.Volume[i]

# %%
new_data = pd.DataFrame({ 
    'date' : date,
    'volume' : volume,
    'open' : start,
    'close': close,
    'ave' : ave })
print(len(new_data))
new_data.head()
# Out:
# 4398
#          date  volume     open    close       ave
# 0  2007-01-01  145690  1.31908  1.31952  1.319300
# 1  2007-01-02   25112  1.32033  1.32106  1.320695
# 2  2007-01-03   24481  1.32762  1.32710  1.327360
# 3  2007-01-04   23233  1.31626  1.31683  1.316545
# 4  2007-01-05   24544  1.30893  1.30845  1.308690

# %%
plt.figure(figsize = (20,6))
sns.lineplot(data=new_data, x="date", y="open")

# %%
plt.figure(figsize = (20,6))
sns.lineplot(data=new_data, x="date", y="close")

# %%
plt.figure(figsize = (20,6))
sns.lineplot(data=new_data, x="date", y="ave")

# %% [markdown]
# # Training and test set Preparation

# %%
ave = [a*100 for a in ave]

# %%
a = 15

# %%
X_data, y_data = [], []
for i in range(a,len(ave)):
    X_data.append( ave[i-a:i] )
    y_data.append( ave[i] )

len(X_data)
# Out:
# 4383

# %%
X_train, X_val, X_test = X_data[:3000], X_data[3000:3350], X_data[3350:]
y_train, y_val, y_test = y_data[:3000], y_data[3000:3350], y_data[3350:]

# %%
def arraying(s):
    return np.array(s)

def shapeshift(s):
    s = arraying(s)
    return np.reshape(s, (s.shape[0], s.shape[1], 1))

X_train, X_val, X_test = shapeshift(X_train), shapeshift(X_val), shapeshift(X_test)
y_train, y_val, y_test = arraying(y_train), arraying(y_val), arraying(y_test)

# %%
X_train.shape
# Out:
# (3000, 15, 1)

# %% [markdown]
# # Building RNN model (LSTM)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras import layers

# %%
model = Sequential([layers.Input((a,1)),
                    layers.LSTM(64),
                    layers.Dense(32, activation = "relu"),
                    layers.Dense(32, activation = "relu"),
                    layers.Dense(1)
                   ])

model.compile(loss="mse", optimizer = "Adam", metrics = ["mean_absolute_error"])

# %%
model.fit(X_train,y_train, validation_data = (X_val, y_val), epochs = 30)
# Out:
# Epoch 1/30
# 94/94 [==============================] - 4s 18ms/step - loss: 13942.1064 - mean_absolute_error: 116.1229 - val_loss: 2005.4557 - val_mean_absolute_error: 44.5476
# Epoch 2/30
# 94/94 [==============================] - 1s 11ms/step - loss: 630.3253 - mean_absolute_error: 17.5706 - val_loss: 475.7740 - val_mean_absolute_error: 21.3458
# Epoch 3/30
# 94/94 [==============================] - 1s 11ms/step - loss: 117.4416 - mean_absolute_error: 8.3279 - val_loss: 196.6527 - val_mean_absolute_error: 13.7086
# Epoch 4/30
# 94/94 [==============================] - 1s 11ms/step - loss: 27.2056 - mean_absolute_error: 3.3316 - val_loss: 1.0177 - val_mean_absolute_error: 0.8430
# Epoch 5/30
# 94/94 [==============================] - 1s 10ms/step - loss: 2.4861 - mean_absolute_error: 0.9863 - val_loss: 0.4421 - val_mean_absolute_error: 0.5426
# Epoch 6/30
# 94/94 [==============================] - 1s 11ms/step - loss: 1.4288 - mean_absolute_error: 0.8455 - val_loss: 0.3309 - val_mean_absolute_error: 0.4585
# Epoch 7/30
# 94/94 [==============================] - 1s 11ms/step - loss: 1.1921 - mean_absolute_error: 0.8021 - val_loss: 0.3274 - val_mean_absolute_error: 0.4449
# Epoch 8/30
# 94/94 [==============================] - 1s 11ms/step - loss: 1.0665 - mean_absolute_error: 0.7669 - val_loss: 0.2985 - val_mean_absolute_error: 0.4199
# Epoch 9/30
# 94/94 [==============================] - 1s 11ms/step - loss: 0.8507 - mean_absolute_error: 0.6685 - val_loss: 0.3176 - val_mean_absolute_error: 0.4363
# Epoch 10/30
# 94/94 [==============================] - 1s 10ms/step - loss: 0.8884 - mean_absolute_error: 0.7123 - val_loss: 0.2897 - val_mean_absolute_error: 0.4183
# Epoch 11/30
# 94/94 [==============================] - 1s 10ms/step - loss: 0.8513 - mean_absolute_error: 0.6761 - val_loss: 0.5447 - val_mean_absolute_error: 0.6196
# Epoch 12/30
# 94/94 [==============================] - 1s 13ms/step - loss: 0.8270 - mean_absolute_error: 0.6752 - val_loss: 0.2985 - val_mean_absolute_error: 0.4261
# Epoch 13/30
# 94/94 [==============================] - 2s 18ms/step - loss: 0.8731 - mean_absolute_error: 0.7049 - val_loss: 0.3704 - val_mean_absolute_error: 0.4755
# Epoch 14/30
# 94/94 [==============================] - 1s 11ms/step - loss: 0.8068 - mean_absolute_error: 0.6654 - val_loss: 0.8118 - val_mean_absolute_error: 0.7583
# Epoch 15/30
# 94/94 [==============================] - 1s 11ms/step - loss: 0.8139 - mean_absolute_error: 0.6685 - val_loss: 0.4936 - val_mean_absolute_error: 0.5876
# Epoch 16/30
# 94/94 [==============================] - 1s 11ms/step - loss: 0.7250 - mean_absolute_error: 0.6242 - val_loss: 0.3687 - val_mean_absolute_error: 0.4840
# Epoch 17/30
# 94/94 [==============================] - 1s 11ms/step - loss: 0.7947 - mean_absolute_error: 0.6564 - val_loss: 0.6225 - val_mean_absolute_error: 0.6841
# Epoch 18/30
# 94/94 [==============================] - 1s 10ms/step - loss: 0.7968 - mean_absolute_error: 0.6635 - val_loss: 0.2557 - val_mean_absolute_error: 0.3830
# Epoch 19/30
# 94/94 [==============================] - 1s 10ms/step - loss: 0.8122 - mean_absolute_error: 0.6665 - val_loss: 0.3368 - val_mean_absolute_error: 0.4645
# Epoch 20/30
# 94/94 [==============================] - 1s 11ms/step - loss: 0.7368 - mean_absolute_error: 0.6320 - val_loss: 0.2568 - val_mean_absolute_error: 0.3888
# Epoch 21/30
# 94/94 [==============================] - 1s 11ms/step - loss: 0.8160 - mean_absolute_error: 0.6757 - val_loss: 0.2788 - val_mean_absolute_error: 0.3985
# Epoch 22/30
# 94/94 [==============================] - 1s 11ms/step - loss: 0.7773 - mean_absolute_error: 0.6530 - val_loss: 0.5531 - val_mean_absolute_error: 0.6105
# Epoch 23/30
# 94/94 [==============================] - 1s 10ms/step - loss: 0.7562 - mean_absolute_error: 0.6467 - val_loss: 0.2445 - val_mean_absolute_error: 0.3726
# Epoch 24/30
# 94/94 [==============================] - 1s 10ms/step - loss: 0.7702 - mean_absolute_error: 0.6521 - val_loss: 0.2817 - val_mean_absolute_error: 0.4146
# Epoch 25/30
# 94/94 [==============================] - 1s 10ms/step - loss: 0.7073 - mean_absolute_error: 0.6134 - val_loss: 0.3189 - val_mean_absolute_error: 0.4502
# Epoch 26/30
# 94/94 [==============================] - 1s 11ms/step - loss: 0.7219 - mean_absolute_error: 0.6205 - val_loss: 0.2693 - val_mean_absolute_error: 0.4035
# Epoch 27/30
# 94/94 [==============================] - 1s 10ms/step - loss: 0.7873 - mean_absolute_error: 0.6485 - val_loss: 0.2969 - val_mean_absolute_error: 0.4307
# Epoch 28/30
# 94/94 [==============================] - 1s 11ms/step - loss: 0.7366 - mean_absolute_error: 0.6331 - val_loss: 0.5556 - val_mean_absolute_error: 0.6111
# Epoch 29/30
# 94/94 [==============================] - 1s 11ms/step - loss: 0.6956 - mean_absolute_error: 0.6038 - val_loss: 0.3837 - val_mean_absolute_error: 0.5138
# Epoch 30/30
# 94/94 [==============================] - 1s 11ms/step - loss: 0.8634 - mean_absolute_error: 0.6984 - val_loss: 0.3182 - val_mean_absolute_error: 0.4573

# %% [markdown]
# # Train Set Results

# %%
y_train_pred = model.predict(X_train)

a, b = 200, 100

plt.figure(figsize = (15,6))
plt.plot(date[b:a], y_train_pred[b:a])
plt.plot(date[b:a], y_train[b:a])
plt.legend(["train preds", "acual vals"])

# %%
plt.figure(figsize = (15,6))
plt.plot(date[:3000], y_train_pred)
plt.plot(date[:3000], y_train)
plt.legend(["train preds", "acual vals"])

# %%
from sklearn.metrics import mean_absolute_error as mae
mae(y_train,y_train_pred)/100
# Out:
# 0.005972729027709962

# %% [markdown]
# # Test set predictions

# %%
y_pred = model.predict(X_test)

a, b = 200, 100

plt.figure(figsize = (15,6))
plt.plot(date[b:a], y_pred[b:a])
plt.plot(date[b:a], y_test[b:a])
plt.legend(["train preds", "acual vals"])

# %%
plt.figure(figsize = (15,6))
plt.plot(date[:1033], y_pred)
plt.plot(date[:1033], y_test)
plt.legend(["test preds", "acual vals"])

# %%
from sklearn.metrics import mean_absolute_error as mae
mae(y_test,y_pred)/100
# Out:
# 0.0037518864324224376
