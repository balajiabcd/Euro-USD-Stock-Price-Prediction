# %% [markdown]
# <a href="https://colab.research.google.com/github/balajiabcd/Euro-USD-Stock-Price-Prediction/blob/main/euro_and_usd_stock_prediction05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Libraries

# %%
import numpy as np
import pandas as pd
from datetime import datetime,timedelta

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
data = pd.read_csv("/content/Entire.csv")
data.head()
# Out:
#                Date     Open     High      Low    Close  Volume
# 0  2020-12-02 09:53  1.20584  1.20586  1.20577  1.20583     263
# 1  2020-12-02 09:54  1.20583  1.20586  1.20577  1.20577     230
# 2  2020-12-02 09:55  1.20575  1.20589  1.20569  1.20586     268
# 3  2020-12-02 10:00  1.20536  1.20564  1.20530  1.20552     298
# 4  2020-12-02 10:01  1.20551  1.20563  1.20525  1.20542     481

# %% [markdown]
# # Data Analysis

# %%
data["Date"] =  [datetime.strptime(a, '%Y-%m-%d %H:%M') for a in data.Date]
data = data.sort_values(by = "Date").reset_index()
data = data.drop("index", axis = 1)
data["date"] =  [a.date() for a in data.Date]

# %%
data.head()
# Out:
#                  Date     Open     High      Low    Close   Volume        date
# 0 2007-01-01 00:00:00  1.31908  1.31973  1.31872  1.31952   145690  2007-01-01
# 1 2007-01-01 00:00:00  1.31908  1.32095  1.31650  1.32058  1946843  2007-01-01
# 2 2007-01-01 01:00:00  1.31908  1.31964  1.31896  1.31913    24827  2007-01-01
# 3 2007-01-01 01:00:00  1.31908  1.31964  1.31894  1.31915    47067  2007-01-01
# 4 2007-01-01 01:30:00  1.31920  1.31943  1.31894  1.31915    22240  2007-01-01

# %%
data.tail()
# Out:
#                       Date     Open     High      Low    Close  Volume  \
# 940398 2021-01-22 22:55:00  1.21701  1.21717  1.21666  1.21667    2352
# 940399 2021-01-22 22:56:00  1.21709  1.21712  1.21706  1.21709     564
# 940400 2021-01-22 22:57:00  1.21709  1.21710  1.21702  1.21706     690
# 940401 2021-01-22 22:58:00  1.21705  1.21709  1.21704  1.21706     473
# 940402 2021-01-22 22:59:00  1.21705  1.21717  1.21666  1.21667     249
#
#               date
# 940398  2021-01-22
# 940399  2021-01-22
# 940400  2021-01-22
# 940401  2021-01-22
# 940402  2021-01-22

# %%
date, volume, start, close, ave  = [],[],[],[],[] 
d, o, c, vol = data.date[0] - timedelta(1), 0, 0, 0
for i in range(len(data)):
    if d != data.date[i]:
        d = data.date[i]
        low_time = data.Date[i].time()
        high_time = data.Date[i].time()
        o, c, vol = data.Open[i], data.Close[i], data.Volume[i]
        date.append(d)
        volume.append(vol)
        start.append(o)
        close.append(c)
        ave.append((o+c)/2)
        
    if low_time > data.Date[i].time():
        low_time = data.Date[i].time()
        o = data.Open[i]
        
    if high_time < data.Date[i].time():
        high_time = data.Date[i].time()
        c = data.Close[i]
        
    if vol != data.Volume[i]:
        vol += data.Volume[i]

# %%
new_data = pd.DataFrame({ 
    'date' : date,
    'volume' : volume,
    'open' : start,
    'close': close,
    'ave' : ave })
print(len(new_data))
new_data.head()
# Out:
# 4398
#          date  volume     open    close       ave
# 0  2007-01-01  145690  1.31908  1.31952  1.319300
# 1  2007-01-02   25112  1.32033  1.32106  1.320695
# 2  2007-01-03   24481  1.32762  1.32710  1.327360
# 3  2007-01-04   23233  1.31626  1.31683  1.316545
# 4  2007-01-05   24544  1.30893  1.30845  1.308690

# %%
plt.figure(figsize = (20,6))
sns.lineplot(data=new_data, x="date", y="open")

# %%
plt.figure(figsize = (20,6))
sns.lineplot(data=new_data, x="date", y="close")

# %%
plt.figure(figsize = (20,6))
sns.lineplot(data=new_data, x="date", y="ave")

# %% [markdown]
# # Training and test set Preparation

# %%
ave = [a*100 for a in ave]

# %%
a = 60

# %%
X_data, y_data = [], []
for i in range(a,len(ave)):
    X_data.append( ave[i-a:i] )
    y_data.append( ave[i] )

len(X_data)
# Out:
# 4338

# %%
X_train, X_val, X_test = X_data[:3000], X_data[3000:3350], X_data[3350:]
y_train, y_val, y_test = y_data[:3000], y_data[3000:3350], y_data[3350:]

# %%
def arraying(s):
    return np.array(s)

def shapeshift(s):
    s = arraying(s)
    return np.reshape(s, (s.shape[0], s.shape[1], 1))

X_train, X_val, X_test = shapeshift(X_train), shapeshift(X_val), shapeshift(X_test)
y_train, y_val, y_test = arraying(y_train), arraying(y_val), arraying(y_test)

# %%
X_train.shape
# Out:
# (3000, 60, 1)

# %% [markdown]
# # Building RNN model (LSTM)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras import layers

# %%
model = Sequential([layers.Input((a,1)),
                    layers.LSTM(64),
                    layers.Dense(32, activation = "relu"),
                    layers.Dense(32, activation = "relu"),
                    layers.Dense(1)
                   ])

model.compile(loss="mse", optimizer = "Adam", metrics = ["mean_absolute_error"])

# %%
model.fit(X_train,y_train, validation_data = (X_val, y_val), epochs = 30)
# Out:
# Epoch 1/30
# 94/94 [==============================] - 6s 39ms/step - loss: 15084.9336 - mean_absolute_error: 121.7082 - val_loss: 4779.8403 - val_mean_absolute_error: 68.9400
# Epoch 2/30
# 94/94 [==============================] - 3s 32ms/step - loss: 1550.1743 - mean_absolute_error: 28.0478 - val_loss: 422.6072 - val_mean_absolute_error: 19.9403
# Epoch 3/30
# 94/94 [==============================] - 3s 32ms/step - loss: 136.2435 - mean_absolute_error: 9.1345 - val_loss: 326.9737 - val_mean_absolute_error: 17.6277
# Epoch 4/30
# 94/94 [==============================] - 3s 32ms/step - loss: 57.9103 - mean_absolute_error: 5.5612 - val_loss: 3.7464 - val_mean_absolute_error: 1.7225
# Epoch 5/30
# 94/94 [==============================] - 4s 43ms/step - loss: 5.8730 - mean_absolute_error: 1.6247 - val_loss: 1.3717 - val_mean_absolute_error: 1.0064
# Epoch 6/30
# 94/94 [==============================] - 3s 32ms/step - loss: 2.6560 - mean_absolute_error: 1.1198 - val_loss: 0.8862 - val_mean_absolute_error: 0.7901
# Epoch 7/30
# 94/94 [==============================] - 3s 32ms/step - loss: 1.8093 - mean_absolute_error: 0.9532 - val_loss: 0.5545 - val_mean_absolute_error: 0.5974
# Epoch 8/30
# 94/94 [==============================] - 3s 32ms/step - loss: 1.2710 - mean_absolute_error: 0.8046 - val_loss: 0.4305 - val_mean_absolute_error: 0.5189
# Epoch 9/30
# 94/94 [==============================] - 3s 31ms/step - loss: 1.1533 - mean_absolute_error: 0.7795 - val_loss: 0.8921 - val_mean_absolute_error: 0.7870
# Epoch 10/30
# 94/94 [==============================] - 3s 32ms/step - loss: 1.0352 - mean_absolute_error: 0.7448 - val_loss: 0.3681 - val_mean_absolute_error: 0.4664
# Epoch 11/30
# 94/94 [==============================] - 3s 31ms/step - loss: 0.8777 - mean_absolute_error: 0.6728 - val_loss: 0.4175 - val_mean_absolute_error: 0.5133
# Epoch 12/30
# 94/94 [==============================] - 3s 32ms/step - loss: 0.8713 - mean_absolute_error: 0.6853 - val_loss: 0.3055 - val_mean_absolute_error: 0.4220
# Epoch 13/30
# 94/94 [==============================] - 3s 31ms/step - loss: 0.8438 - mean_absolute_error: 0.6711 - val_loss: 0.3363 - val_mean_absolute_error: 0.4420
# Epoch 14/30
# 94/94 [==============================] - 3s 31ms/step - loss: 0.8070 - mean_absolute_error: 0.6652 - val_loss: 0.3437 - val_mean_absolute_error: 0.4400
# Epoch 15/30
# 94/94 [==============================] - 3s 32ms/step - loss: 0.7729 - mean_absolute_error: 0.6367 - val_loss: 0.3390 - val_mean_absolute_error: 0.4427
# Epoch 16/30
# 94/94 [==============================] - 3s 31ms/step - loss: 0.7832 - mean_absolute_error: 0.6513 - val_loss: 0.2781 - val_mean_absolute_error: 0.4015
# Epoch 17/30
# 94/94 [==============================] - 3s 32ms/step - loss: 0.7374 - mean_absolute_error: 0.6239 - val_loss: 0.2679 - val_mean_absolute_error: 0.3862
# Epoch 18/30
# 94/94 [==============================] - 3s 31ms/step - loss: 0.7431 - mean_absolute_error: 0.6291 - val_loss: 0.2703 - val_mean_absolute_error: 0.3933
# Epoch 19/30
# 94/94 [==============================] - 3s 32ms/step - loss: 0.7755 - mean_absolute_error: 0.6521 - val_loss: 0.2782 - val_mean_absolute_error: 0.3883
# Epoch 20/30
# 94/94 [==============================] - 3s 32ms/step - loss: 0.7692 - mean_absolute_error: 0.6422 - val_loss: 0.3433 - val_mean_absolute_error: 0.4685
# Epoch 21/30
# 94/94 [==============================] - 3s 31ms/step - loss: 0.7932 - mean_absolute_error: 0.6610 - val_loss: 0.2674 - val_mean_absolute_error: 0.3922
# Epoch 22/30
# 94/94 [==============================] - 3s 31ms/step - loss: 0.6965 - mean_absolute_error: 0.5974 - val_loss: 0.2815 - val_mean_absolute_error: 0.4016
# Epoch 23/30
# 94/94 [==============================] - 3s 31ms/step - loss: 0.7306 - mean_absolute_error: 0.6261 - val_loss: 0.2822 - val_mean_absolute_error: 0.4011
# Epoch 24/30
# 94/94 [==============================] - 3s 32ms/step - loss: 0.8882 - mean_absolute_error: 0.7131 - val_loss: 0.2735 - val_mean_absolute_error: 0.3896
# Epoch 25/30
# 94/94 [==============================] - 3s 32ms/step - loss: 0.7450 - mean_absolute_error: 0.6328 - val_loss: 0.2789 - val_mean_absolute_error: 0.3963
# Epoch 26/30
# 94/94 [==============================] - 4s 46ms/step - loss: 0.7104 - mean_absolute_error: 0.6133 - val_loss: 0.2630 - val_mean_absolute_error: 0.3870
# Epoch 27/30
# 94/94 [==============================] - 3s 33ms/step - loss: 0.7156 - mean_absolute_error: 0.6188 - val_loss: 0.2593 - val_mean_absolute_error: 0.3812
# Epoch 28/30
# 94/94 [==============================] - 3s 32ms/step - loss: 0.6659 - mean_absolute_error: 0.5901 - val_loss: 0.5663 - val_mean_absolute_error: 0.6433
# Epoch 29/30
# 94/94 [==============================] - 3s 32ms/step - loss: 0.7676 - mean_absolute_error: 0.6522 - val_loss: 0.2704 - val_mean_absolute_error: 0.3968
# Epoch 30/30
# 94/94 [==============================] - 3s 32ms/step - loss: 0.6642 - mean_absolute_error: 0.5864 - val_loss: 0.3592 - val_mean_absolute_error: 0.4527

# %% [markdown]
# # Train Set Results

# %%
y_train_pred = model.predict(X_train)

a, b = 200, 100

plt.figure(figsize = (15,6))
plt.plot(date[b:a], y_train_pred[b:a])
plt.plot(date[b:a], y_train[b:a])
plt.legend(["train preds", "acual vals"])

# %%
plt.figure(figsize = (15,6))
plt.plot(date[:3000], y_train_pred)
plt.plot(date[:3000], y_train)
plt.legend(["train preds", "acual vals"])

# %%
from sklearn.metrics import mean_absolute_error as mae
mae(y_train,y_train_pred)/100
# Out:
# 0.0056316270607503225

# %% [markdown]
# # Test set predictions

# %%
y_pred = model.predict(X_test)

a, b = 200, 100

plt.figure(figsize = (15,6))
plt.plot(date[b:a], y_pred[b:a])
plt.plot(date[b:a], y_test[b:a])
plt.legend(["train preds", "acual vals"])

# %%
plt.figure(figsize = (15,6))
plt.plot(date[:988], y_pred)
plt.plot(date[:988], y_test)
plt.legend(["test preds", "acual vals"])

# %%
from sklearn.metrics import mean_absolute_error as mae
mae(y_test,y_pred)/100
# Out:
# 0.004278544967589588
